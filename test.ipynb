# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pn
#
# ModuleNotFoundError: No module named 'pandas'

# %%
print(5)
# Out:
# 5

# %%
pip install matplotlib
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns 
plt.style.use('ggplot')


Df1 = pd.read_csv('players.csv')
Df1


Df1.head()
# Out:
#               PlayerName                Post  Age MarketValue  Nationality  \
# 0          Kylian Mbappé      Centre-Forward   25     180.00m       France
# 1         Victor Osimhen      Centre-Forward   25     100.00m      Nigeria
# 2         Julián Alvarez      Centre-Forward   24      90.00m    Argentina
# 3  Khvicha Kvaratskhelia         Left Winger   23      85.00m      Georgia
# 4            Xavi Simons  Attacking Midfield   21      80.00m  Netherlands
#
#                   Left         Current_team            Fee
# 0  Paris Saint-Germain          Real Madrid  free transfer
# 1           SSC Napoli          Galatasaray  loan transfer
# 2      Manchester City   Atlético de Madrid         75.00m
# 3           SSC Napoli  Paris Saint-Germain         70.00m
# 4  Paris Saint-Germain           RB Leipzig         50.00m

# %%
Df1.tail()
# Out:
#           PlayerName                Post  Age MarketValue Nationality  \
# 1970     Lukas Engel           Left-Back   26       2.20m     Denmark
# 1971   Conrad Wallem      Right Midfield   24       2.20m      Norway
# 1972    Juan Córdoba        Right Winger   21       1.20m    Colombia
# 1973  Dorukhan Toköz    Central Midfield   28       2.10m     Türkiye
# 1974        Thaciano  Attacking Midfield   29       2.00m      Brazil
#
#                      Left       Current_team            Fee
# 1970     Middlesbrough FC      FC Cincinnati  loan transfer
# 1971     SK Slavia Prague  St. Louis CITY SC  loan transfer
# 1972       Deportivo Cali  GNK Dinamo Zagreb              0
# 1973      Adana Demirspor           Eyüpspor  free transfer
# 1974  Esporte Clube Bahia          Santos FC              0

# %%
Df1.shape
# Out:
# (1975, 8)

# %%
Df1.dtypes
# Out:
# PlayerName        str
# Post              str
# Age             int64
# MarketValue       str
# Nationality       str
# Left              str
# Current_team      str
# Fee               str
# dtype: object

# %%
Df1.describe()
# Out:
#                Age
# count  1975.000000
# mean     24.632911
# std       3.666220
# min      16.000000
# 25%      22.000000
# 50%      24.000000
# 75%      27.000000
# max      37.000000

# %%
Df1.columns
# Out:
# Index(['PlayerName', 'Post', 'Age', 'MarketValue', 'Nationality', 'Left',
#        'Current_team', 'Fee'],
#       dtype='str')

# %%
Df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1975 entries, 0 to 1974
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PlayerName    1975 non-null   str
#  1   Post          1975 non-null   str
#  2   Age           1975 non-null   int64
#  3   MarketValue   1975 non-null   str
#  4   Nationality   1975 non-null   str
#  5   Left          1975 non-null   str
#  6   Current_team  1975 non-null   str
#  7   Fee           1975 non-null   str
# dtypes: int64(1), str(7)
# memory usage: 123.6 KB

# %%
Df1['Age'].head
# Out:
# <bound method NDFrame.head of 0       25
# 1       25
# 2       24
# 3       23
# 4       21
#         ..
# 1970    26
# 1971    24
# 1972    21
# 1973    28
# 1974    29
# Name: Age, Length: 1975, dtype: int64>

# %%
Df1.loc[0]
# Out:
# PlayerName            Kylian Mbappé
# Post                 Centre-Forward
# Age                              25
# MarketValue                 180.00m
# Nationality                  France
# Left            Paris Saint-Germain
# Current_team            Real Madrid
# Fee                   free transfer
# Name: 0, dtype: object

# %%
Df1.iloc[5]
# Out:
# PlayerName          Jhon Durán
# Post            Centre-Forward
# Age                         21
# MarketValue             40.00m
# Nationality           Colombia
# Left               Aston Villa
# Current_team       Al-Nassr FC
# Fee                          0
# Name: 5, dtype: object

# %%
Df1[Df1['Age']>20]
# Out:
#                  PlayerName                Post  Age MarketValue  Nationality  \
# 0             Kylian Mbappé      Centre-Forward   25     180.00m       France
# 1            Victor Osimhen      Centre-Forward   25     100.00m      Nigeria
# 2            Julián Alvarez      Centre-Forward   24      90.00m    Argentina
# 3     Khvicha Kvaratskhelia         Left Winger   23      85.00m      Georgia
# 4               Xavi Simons  Attacking Midfield   21      80.00m  Netherlands
# ...                     ...                 ...  ...         ...          ...
# 1970            Lukas Engel           Left-Back   26       2.20m      Denmark
# 1971          Conrad Wallem      Right Midfield   24       2.20m       Norway
# 1972           Juan Córdoba        Right Winger   21       1.20m     Colombia
# 1973         Dorukhan Toköz    Central Midfield   28       2.10m      Türkiye
# 1974               Thaciano  Attacking Midfield   29       2.00m       Brazil
#
# ...

# %%
Df1['Age'].mean()
# Out:
# np.float64(24.632911392405063)

# %%
Df1['Age'].median()
# Out:
# np.float64(24.0)

# %%
Df1['Post'].value_counts()
# Out:
# Post
# Centre-Forward        381
# Centre-Back           319
# Central Midfield      234
# Left Winger           205
# Right Winger          172
# Attacking Midfield    159
# Defensive Midfield    158
# Left-Back             116
# Right-Back            111
# Goalkeeper             84
# Second Striker         16
# Left Midfield          11
# Right Midfield          9
# Name: count, dtype: int64

# %%
Df1.sort_values('Post', ascending=False).head()
# Out:
#                PlayerName            Post  Age MarketValue Nationality  \
# 1140         Armindo Sieb  Second Striker   21       4.00m     Germany
# 722                Cristo  Second Striker   26       6.00m       Spain
# 945   Sebastiano Esposito  Second Striker   22       5.00m       Italy
# 1142            Stoichkov  Second Striker   30       4.00m       Spain
# 86     Albert Gudmundsson  Second Striker   27      30.00m     Iceland
#
#                Left      Current_team             Fee
# 1140  Bayern Munich    1.FSV Mainz 05  Loan fee:1.00m
# 722       FC Arouca        Al-Sadd SC               0
# 945     Inter Milan         FC Empoli   loan transfer
# 1142       SD Eibar  Deportivo Alavés           1.00m
# 86        Genoa CFC    ACF Fiorentina  Loan fee:5.85m

# %%
Df1.isnull().sum()
# Out:
# PlayerName      0
# Post            0
# Age             0
# MarketValue     0
# Nationality     0
# Left            0
# Current_team    0
# Fee             0
# dtype: int64

# %%
Df1.fillna(Df1['Age'].mean()).head
# Out:
# <bound method NDFrame.head of                  PlayerName                Post  Age MarketValue  Nationality  \
# 0             Kylian Mbappé      Centre-Forward   25     180.00m       France
# 1            Victor Osimhen      Centre-Forward   25     100.00m      Nigeria
# 2            Julián Alvarez      Centre-Forward   24      90.00m    Argentina
# 3     Khvicha Kvaratskhelia         Left Winger   23      85.00m      Georgia
# 4               Xavi Simons  Attacking Midfield   21      80.00m  Netherlands
# ...                     ...                 ...  ...         ...          ...
# 1970            Lukas Engel           Left-Back   26       2.20m      Denmark
# 1971          Conrad Wallem      Right Midfield   24       2.20m       Norway
# 1972           Juan Córdoba        Right Winger   21       1.20m     Colombia
# 1973         Dorukhan Toköz    Central Midfield   28       2.10m      Türkiye
# 1974               Thaciano  Attacking Midfield   29       2.00m       Brazil
#
# ...

# %%
Df1
# Out:
#                  PlayerName                Post  Age MarketValue  Nationality  \
# 0             Kylian Mbappé      Centre-Forward   25     180.00m       France
# 1            Victor Osimhen      Centre-Forward   25     100.00m      Nigeria
# 2            Julián Alvarez      Centre-Forward   24      90.00m    Argentina
# 3     Khvicha Kvaratskhelia         Left Winger   23      85.00m      Georgia
# 4               Xavi Simons  Attacking Midfield   21      80.00m  Netherlands
# ...                     ...                 ...  ...         ...          ...
# 1970            Lukas Engel           Left-Back   26       2.20m      Denmark
# 1971          Conrad Wallem      Right Midfield   24       2.20m       Norway
# 1972           Juan Córdoba        Right Winger   21       1.20m     Colombia
# 1973         Dorukhan Toköz    Central Midfield   28       2.10m      Türkiye
# 1974               Thaciano  Attacking Midfield   29       2.00m       Brazil
#
# ...

# %%
Df1.groupby('Age')['MarketValue']

# %%
pd.merge(Df1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 pd.merge(Df1)
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
arr = np.array(Df1)
type(arr)
arr.dtype
# Out:
# dtype('O')

# %%
Df1.drop(['Fee'],axis =1 )
# Out:
#                  PlayerName                Post  Age MarketValue  Nationality  \
# 0             Kylian Mbappé      Centre-Forward   25     180.00m       France
# 1            Victor Osimhen      Centre-Forward   25     100.00m      Nigeria
# 2            Julián Alvarez      Centre-Forward   24      90.00m    Argentina
# 3     Khvicha Kvaratskhelia         Left Winger   23      85.00m      Georgia
# 4               Xavi Simons  Attacking Midfield   21      80.00m  Netherlands
# ...                     ...                 ...  ...         ...          ...
# 1970            Lukas Engel           Left-Back   26       2.20m      Denmark
# 1971          Conrad Wallem      Right Midfield   24       2.20m       Norway
# 1972           Juan Córdoba        Right Winger   21       1.20m     Colombia
# 1973         Dorukhan Toköz    Central Midfield   28       2.10m      Türkiye
# 1974               Thaciano  Attacking Midfield   29       2.00m       Brazil
#
# ...

# %%
Df1 =Df1.rename(columns={'Age':'age'})

# %%
Df1.isna().sum()
# Out:
# PlayerName      0
# Post            0
# age             0
# MarketValue     0
# Nationality     0
# Left            0
# Current_team    0
# Fee             0
# dtype: int64

# %%
Df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1970    False
# 1971    False
# 1972    False
# 1973    False
# 1974    False
# Length: 1975, dtype: bool

# %%
Df1.loc[Df1.duplicated(subset='Nationality')].head
# Out:
# <bound method NDFrame.head of             PlayerName                Post  age MarketValue  Nationality  \
# 8     Matthijs de Ligt         Centre-Back   25      65.00m  Netherlands
# 10           Leny Yoro         Centre-Back   18      50.00m       France
# 13        Moussa Diaby        Right Winger   25      55.00m       France
# 14           Dani Olmo  Attacking Midfield   26      60.00m        Spain
# 15             Endrick      Centre-Forward   18      60.00m       Brazil
# ...                ...                 ...  ...         ...          ...
# 1970       Lukas Engel           Left-Back   26       2.20m      Denmark
# 1971     Conrad Wallem      Right Midfield   24       2.20m       Norway
# 1972      Juan Córdoba        Right Winger   21       1.20m     Colombia
# 1973    Dorukhan Toköz    Central Midfield   28       2.10m      Türkiye
# 1974          Thaciano  Attacking Midfield   29       2.00m       Brazil
#
# ...

# %%
Df1.duplicated(subset=['Age'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22220\3868122268.py in ?()
# ----> 1 Df1.duplicated(subset=['Age'])
#
# d:\Новая папка\venv\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep)
#    8067         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    8068         # key that doesn't exist.
#    8069         diff = set(subset) - set(self.columns)
#    8070         if diff:
# -> 8071             raise KeyError(Index(diff))
#    8072
#    8073         if len(subset) == 1 and self.columns.is_unique:
#    8074             # GH#45236 This is faster than get_group_index below
#
# KeyError: Index(['Age'], dtype='str')

# %%
f = Df1['age'].value_counts().head().plot(kind='bar',title='The most common ages')
f.set_xlabel("Age")
f.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
Df1['age'].plot(kind='hist')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Новая папка\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 Df1['Age'].plot(kind='hist')
#
# ...

# %%
Df1['age'].plot(kind='hist',bins=22, title='fhe')
# Out:
# <Axes: title={'center': 'fhe'}, ylabel='Frequency'>

# %%
ax= Df1['age'].plot(kind='kde', title='fhe')
ax.set_xlabel(Df1)
# Out:
# Text(0.5, 0, '                 PlayerName                Post  age MarketValue  Nationality  \\\n0             Kylian Mbappé      Centre-Forward   25     180.00m       France   \n1            Victor Osimhen      Centre-Forward   25     100.00m      Nigeria   \n2            Julián Alvarez      Centre-Forward   24      90.00m    Argentina   \n3     Khvicha Kvaratskhelia         Left Winger   23      85.00m      Georgia   \n4               Xavi Simons  Attacking Midfield   21      80.00m  Netherlands   \n...                     ...                 ...  ...         ...          ...   \n1970            Lukas Engel           Left-Back   26       2.20m      Denmark   \n1971          Conrad Wallem      Right Midfield   24       2.20m       Norway   \n1972           Juan Córdoba        Right Winger   21       1.20m     Colombia   \n1973         Dorukhan Toköz    Central Midfield   28       2.10m      Türkiye   \n1974               Thaciano  Attacking Midfield   29       2.00m       Brazil   \
# ...

# %%
Df1.groupby('Age')['MarketValue']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 Df1.groupby('Age')['MarketValue']
#
# File d:\Новая папка\venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File d:\Новая папка\venv\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
#   10815     raise TypeError("You have to supply one of 'by' and 'level'")
# > 10817 return DataFrameGroupBy(
#   10818     obj=self,
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "Ss": [1, 2, 3, 4, 5],
    "ff": [2, 4, 6, 8, 10]
})

ax = Df1.plot(kind='scatter', x='age', y='dshf', title="Scatter Example")
ax.set_xlabel("Ss values")
ax.set_ylabel("ff values")

plt.show()

# %%
sns.scatterplot( x='age',hue='dshf', y='dshf', data = Df1)
# Out:
# <Axes: xlabel='age', ylabel='dshf'>

# %%
Df1['dshf']=Df1['age']/100

# %%
Df1.head()
# Out:
#               PlayerName                Post  age MarketValue  Nationality  \
# 0          Kylian Mbappé      Centre-Forward   25     180.00m       France
# 1         Victor Osimhen      Centre-Forward   25     100.00m      Nigeria
# 2         Julián Alvarez      Centre-Forward   24      90.00m    Argentina
# 3  Khvicha Kvaratskhelia         Left Winger   23      85.00m      Georgia
# 4            Xavi Simons  Attacking Midfield   21      80.00m  Netherlands
#
#                   Left         Current_team            Fee  dshf
# 0  Paris Saint-Germain          Real Madrid  free transfer  0.25
# 1           SSC Napoli          Galatasaray  loan transfer  0.25
# 2      Manchester City   Atlético de Madrid         75.00m  0.24
# 3           SSC Napoli  Paris Saint-Germain         70.00m  0.23
# 4  Paris Saint-Germain           RB Leipzig         50.00m  0.21

# %%
sns.scatterplot( x='age', y='dshf', data = Df1)
# Out:
# <Axes: xlabel='age', ylabel='dshf'>

# %%
sns.pairplot(Df1,vars=['age','dshf'],hue='dshf')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fc = Df1[['age','dshf']].dropna().corr()
fc
# Out:
#       age  dshf
# age   1.0   1.0
# dshf  1.0   1.0

# %%
sns.heatmap(fc,annot=True)
# Out:
# <Axes: >

# %%
a =Df1.query('age!=24').groupby('age')['dshf'].agg(['mean','count']).sort_values('mean').plot(kind='barh',figsize=(10,5),title='frm')
a.set_xlabel
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
g = np.array(Df1['age'])
print(type(g))
print(g)
g
print(g.ndim)
print(g[g>=20])
# Out:
# <class 'numpy.ndarray'>
# [25 25 24 ... 21 28 29]
# 1
# [25 25 24 ... 21 28 29]
